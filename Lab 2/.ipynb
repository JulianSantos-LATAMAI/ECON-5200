# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianSantos-LATAMAI/ECON-5200/blob/main/Lab%202/.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cpi_2026 = 325

# %%
cpi_2026
# Out:
# 325

# %%
cpi_1885 = 9.1

# %%
raito_cpi_1885_2026 = cpi_2026/ cpi_1885

# %%
print(raito_cpi_1885_2026)
# Out:
# 35.714285714285715

# %%
real_price =0.02 * raito_cpi_1885_2026
print(real_price)
# Out:
# 0.7142857142857143

# %%
rgdp = [1,2,3,4,5,6]

# %%
rgdp
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nations = ["A","B","C","D","E","F"]

# %%
nations
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
dict = {
    "nations": nations,
    "rgdp": rgdp,
    "inflation": [1, 2, 3, 3, 2, 1],
    "unemp": [1, 2, 3, 4, 5, 6]
}

# %%
dict
# Out:
# {'nations': ['A', 'B', 'C', 'D', 'E', 'F'],
#  'rgdp': [1, 2, 3, 4, 5, 6],
#  'inflation': [1, 2, 3, 3, 2, 1],
#  'unemp': [1, 2, 3, 4, 5, 6]}

# %%
import pandas as pd

# %%
data = pd.DataFrame(dict)

# %%
data.head()
# Out:
#   nations  rgdp  inflation  unemp
# 0       A     1          1      1
# 1       B     2          2      2
# 2       C     3          3      3
# 3       D     4          3      4
# 4       E     5          2      5

# %%
data = ['misery_index'] = data ['inflation'] + data ['unemp']
# Out:
#   File "/tmp/ipython-input-2389421333.py", line 1
#     data = ['misery_index'] = data ['inflation'] + data ['unemp']
#             ^
# SyntaxError: cannot assign to literal

# %%
nations
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
for i in nations:
  print (i)
# Out:
# A
# B
# C
# D
# E
# F

# %%
for i in rgdp:
  if i > 3:
    print (i)
# Out:
# 4
# 5
# 6

# %%
len(data)
# Out:
# 6

# %%
for i in range(len(data)):
    if data.loc[i, "rgdp"] > 3:
        print(data.loc[i, "nations"])
# Out:
# D
# E
# F
